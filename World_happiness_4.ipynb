# %% [markdown]
# <a href="https://colab.research.google.com/github/bonareri/Python-Data-Analysis/blob/main/World_happiness_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install plotly

# %%
import plotly.express as px

# %%
# !pip install fiona
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 56.5 MB/s eta 0:00:00
# ...

# %%
# !pip install pyogrio

# %%
# !pip install geopandas

# %%
import pyogrio
import geopandas as gpd

# %%
# GeoJSON URL
url = "https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_50m_admin_0_countries.geojson"

# Load the GeoJSON data
gdf = gpd.read_file(url)

# Display some basic information
gdf
# Out:
#      scalerank  labelrank      sovereignt sov_a3  adm0_dif  level  \
# 0            3          5     Netherlands    NL1         1      2
# 1            1          3     Afghanistan    AFG         0      2
# 2            1          3          Angola    AGO         0      2
# 3            1          6  United Kingdom    GB1         1      2
# 4            1          6         Albania    ALB         0      2
# ..         ...        ...             ...    ...       ...    ...
# 236          1          4           Samoa    WSM         0      2
# 237          1          3           Yemen    YEM         0      2
# 238          1          2    South Africa    ZAF         0      2
# 239          1          3          Zambia    ZMB         0      2
# 240          1          3        Zimbabwe    ZWE         0      2
#
#                   type         admin adm0_a3  geou_dif  ... region_un  \
# 0              Country         Aruba     ABW         0  ...  Americas
# ...

# %%
happiness = pd.read_csv('/content/combined (World Happiness Data)_combined.csv')

# %%
happiness_2 = happiness.merge(gdf, how='inner', right_on='admin', left_on='Country')
happiness_2
# Out:
#                       Country                           Region  reset filters  \
# 0                 Switzerland                   Western Europe  Reset Filters
# 1                     Iceland                   Western Europe  Reset Filters
# 2                     Denmark                   Western Europe  Reset Filters
# 3                      Norway                   Western Europe  Reset Filters
# 4                      Canada                    North America  Reset Filters
# ..                        ...                              ...            ...
# 731                     Yemen  Middle East and Northern Africa  Reset Filters
# 732                    Rwanda               Sub-Saharan Africa  Reset Filters
# 733               Afghanistan                    Southern Asia  Reset Filters
# 734  Central African Republic               Sub-Saharan Africa  Reset Filters
# 735               South Sudan               Sub-Saharan Africa  Reset Filters
#
# ...

# %%
dropping = ['scalerank', 'labelrank',
       'sovereignt', 'sov_a3', 'adm0_dif', 'level', 'type', 'admin', 'adm0_a3',
       'geou_dif', 'geounit', 'gu_a3', 'su_dif', 'subunit', 'su_a3',
       'brk_diff', 'name', 'name_long', 'brk_a3', 'brk_name', 'brk_group',
       'abbrev', 'postal', 'formal_en', 'formal_fr', 'note_adm0', 'note_brk',
       'name_sort', 'name_alt', 'mapcolor7', 'mapcolor8', 'mapcolor9',
       'mapcolor13', 'pop_est', 'gdp_md_est', 'pop_year', 'lastcensus',
       'gdp_year', 'economy', 'income_grp', 'wikipedia', 'fips_10', 'iso_a2',
       'iso_a3', 'iso_n3', 'un_a3', 'wb_a2', 'wb_a3', 'woe_id', 'adm0_a3_is',
       'adm0_a3_us', 'adm0_a3_un', 'adm0_a3_wb', 'continent', 'region_un',
       'subregion', 'region_wb', 'name_len', 'long_len', 'abbrev_len', 'tiny',
       'homepart', 'featureclass']

happiness_2.drop(columns=dropping, inplace=True)

# %%
happiness_2 = gpd.GeoDataFrame(happiness_2, geometry='geometry')

# %%
fig, ax=plt.subplots(1, 1, figsize=(15, 10))
happiness_2.plot(column='Happiness Score', ax=ax, legend=True, cmap='viridis', legend_kwds={'label': "Happiness Score by Country",
                              'orientation': "horizontal"})
plt.title('Global Happiness Score by Country')
plt.show()

# %%
happiness.isnull().sum()
# Out:
# Country                         0
# Region                          0
# reset filters                   0
# Year                            0
# Corruption Rank                 1
# Economy (GDP per Capita)        0
# Economy Rank                    0
# Freedom Rank                    0
# Freedom to make life choices    0
# Generosity                      0
# Generosity Rank                 0
# Happiness Rank                  0
# Happiness Score                 0
# Health (Life Expectancy)        0
# Health Rank                     0
# Perception of Corruption        1
# Social support                  0
# Social Support Rank             0
# dtype: int64

# %%
happiness.dropna(inplace=True)

# %%
happiness.isnull().sum()
# Out:
# Country                         0
# Region                          0
# reset filters                   0
# Year                            0
# Corruption Rank                 0
# Economy (GDP per Capita)        0
# Economy Rank                    0
# Freedom Rank                    0
# Freedom to make life choices    0
# Generosity                      0
# Generosity Rank                 0
# Happiness Rank                  0
# Happiness Score                 0
# Health (Life Expectancy)        0
# Health Rank                     0
# Perception of Corruption        0
# Social support                  0
# Social Support Rank             0
# dtype: int64

# %% [markdown]
# #Analysis for Sub-Saharan-Africa countries
#
#
# This analysis investigates the factors contributing to happiness by comparing the happiest countries in Africa, using GDP per capita, social support, and freedom to make life choices as key indicators.

# %%
# First, standardize the names in the 'Country' column to avoid duplicates due to minor differences in spelling or formatting
happiness['Country'] = happiness['Country'].replace(['Somaliland Region', 'Somaliland region'], 'Somaliland Region')

# Alternatively, if there are duplicate rows, you can remove them like this
happiness.drop_duplicates(subset=['Country', 'Region', 'Year'], inplace=True)

# Now, you can confirm that 'Somaliland Region' appears only once
print(happiness[happiness['Country'] == 'Somaliland Region'])
# Out:
#                Country              Region  reset filters  Year  \
# 90   Somaliland Region  Sub-Saharan Africa  Reset Filters  2015
# 254  Somaliland Region  Sub-Saharan Africa  Reset Filters  2016
#
#      Corruption Rank  Economy (GDP per Capita)  Economy Rank  Freedom Rank  \
# 90               9.0                   0.18847           150            69
# 254              9.0                   0.25558           150            81
#
#      Freedom to make life choices  Generosity  Generosity Rank  \
# 90                        0.46582     0.50318                6
# 254                       0.39130     0.51479                5
#
#      Happiness Rank  Happiness Score  Health (Life Expectancy)  Health Rank  \
# 90               91            5.057                   0.43873          119
# 254              97            5.057                   0.33108          125
#
#      Perception of Corruption  Social support  Social Support Rank
# ...

# %% [markdown]
# ##Happiest countries in Africa

# %%
# Filter the data for African countries only (Sub-Saharan Africa and Middle East and Northern Africa)
african_countries_data = happiness[happiness['Region'].isin(['Sub-Saharan Africa'])].drop_duplicates(subset='Country')

# Create a scatter plot with Plotly Express
fig = px.scatter(
    african_countries_data,
    x='Economy (GDP per Capita)',
    y='Happiness Score',
    trendline='ols',  # Adds an Ordinary Least Squares (OLS) regression line
    title="Relationship between GDP per Capita and Happiness Score in African Countries",
    labels={
        'Economy (GDP per Capita)': 'GDP per Capita',
        'Happiness Score': 'Happiness Score'
    },
    hover_name='Country',
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Low GDP, Yet Reasonable Happiness
# Many African nations struggle with low GDP per capita, reflecting their economic difficulties. Countries such as the Somalia, Congo, and Malawi have GDPs far below the global average. They face systemic challenges such as limited industrialization, dependence on agriculture, and political instability. However, these economic realities do not always equate to low happiness scores.
#
# The paradox here is that while these countries may not have vast economic resources, they often score reasonably well in happiness rankings. The reasons for this can be understood through factors beyond mere economic wealth.

# %%
# Create a scatter plot for Social Support vs Happiness Score
fig = px.scatter(
    african_countries_data,
    x='Social support',
    y='Happiness Score',
    trendline='ols',  # Adds an Ordinary Least Squares (OLS) regression line
    title="Relationship between Social Support and Happiness Score in African Countries",
    labels={
        'Social support': 'Social Support',
        'Happiness Score': 'Happiness Score'
    },
    hover_name='Country',
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Social Support: The Heart of African Happiness
#
# Social support plays a vital role in shaping happiness in Africa, often serving as a more powerful driver of well-being than material wealth. Despite many African countries experiencing low GDPs, social support — through family, community, and cultural bonds — remains a key factor in overall life satisfaction.
#
# Even in nations with lower GDPs, such as Sudan, Uganda, and Rwanda, the emphasis on communal ties and collective well-being allows people to find joy in shared experiences, even when financial conditions are not ideal.

# %%
import plotly.express as px

# Filter the data for African countries only (Sub-Saharan Africa)
african_countries_data = happiness[happiness['Region'].isin(['Sub-Saharan Africa'])].drop_duplicates(subset='Country')

# Create a scatter plot for Freedom to make life choices vs Happiness Score
fig = px.scatter(
    african_countries_data,
    x='Freedom to make life choices',
    y='Happiness Score',
    trendline='ols',  # Adds an Ordinary Least Squares (OLS) regression line
    title="Relationship between Freedom to Make Life Choices and Happiness Score in African Countries",
    labels={
        'Freedom to make life choices': 'Freedom to Make Life Choices',
        'Happiness Score': 'Happiness Score'
    },
    hover_name='Country',
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Filter the data for African countries only (Sub-Saharan Africa and Middle East and Northern Africa)
african_countries_data = happiness[happiness['Region'].isin(['Sub-Saharan Africa'])].drop_duplicates(subset='Country')


# Sort the countries by Happiness Score in descending order
sorted_african_countries = african_countries_data.sort_values(by='Happiness Score', ascending=False)

# Get the top 5 happiest countries
top_5_happiest_african_countries = sorted_african_countries[['Country', 'Happiness Score']].head(10)

# Plot the top 5 happiest countries in Africa
plt.figure(figsize=(10, 6))
sns.barplot(x='Happiness Score', y='Country', data=top_5_happiest_african_countries, palette='viridis')
plt.title('Top 10 Happiest Countries in Africa')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-18-cd49d46a3317>:13: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ##Comparison of key factors contributing to happiness for the Top 4 countries

# %%
# Filter for the specific countries we want to analyze
top_happy_countries = happiness[happiness['Country'].isin(['Mauritius', 'Somalia', 'Nigeria', 'Zambia'])]

# Melt the data to create a long format for Plotly Express
melted_data = top_happy_countries.melt(
    id_vars=['Country'],
    value_vars=['Economy (GDP per Capita)', 'Social support', 'Freedom to make life choices'],
    var_name='Factor',
    value_name='Score'
)

# Create a bar plot with Plotly Express
fig = px.bar(
    melted_data,
    x='Country',
    y='Score',
    color='Factor',
    barmode='group',
    title='Comparison of Key Factors Contributing to Happiness in Mauritius, Somalia, Nigeria, and Zambia',
    labels={'Score': 'Score', 'Country': 'Country'},
)

# Update layout for readability
fig.update_layout(
    xaxis_title='Country',
    yaxis_title='Score',
    legend_title='Happiness Factors'
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Summary of Insights on Happiness Factors in Africa: Mauritius, Nigeria, Zambia, and Somalia
#
# ### 1. **Mauritius**
# - **GDP per Capita**: Mauritius leads with the highest GDP per capita among the four countries. This economic advantage influences quality of life, access to healthcare, and educational resources. Economic stability contributes to improved infrastructure, public services, and job opportunities, which positively impact the happiness of its citizens.
# - **Social Support**: Mauritius excels in social support, with strong community bonds, family support, and government welfare programs. This robust social network is a vital component of happiness, as social connections enhance the sense of belonging and satisfaction.
# - **Freedom to Make Life Choices**: Citizens in Mauritius experience high levels of personal freedom, enabling them to make choices regarding careers, education, and lifestyle. This freedom leads to greater satisfaction and fulfillment, as people feel more empowered.
#
# ### 2. **Nigeria**
# - **GDP per Capita**: Nigeria ranks second among these countries in terms of GDP per capita, benefiting from its oil-based economy. However, income inequality and regional disparities affect the overall distribution of wealth, impacting citizens’ happiness.
# - **Social Support**: Nigeria has a strong social fabric, supported by familial and community networks, which contributes to resilience and satisfaction.
# - **Freedom to Make Life Choices**: Nigeria faces challenges related to freedom due to socio-political constraints, which may affect citizens' overall happiness by limiting personal and economic freedoms.
#
# ### 3. **Zambia**
# - **GDP per Capita**: Zambia’s GDP per capita is moderate. The economy faces challenges due to limited diversification, affecting job opportunities and income levels for many.
# - **Social Support**: Social support is strong in Zambia, with community and familial networks providing a sense of belonging.
# - **Freedom to Make Life Choices**: Freedom in Zambia is moderate. While individuals can make personal choices, economic constraints can limit broader opportunities, impacting overall happiness.
#
# ### 4. **Somalia**
# - **GDP per Capita**: Somalia has the lowest GDP per capita among these countries. Economic challenges and instability affect access to basic services and opportunities, impacting the happiness levels of its citizens.
# - **Social Support**: Social support in Somalia is robust despite challenges, as community reliance is crucial in the face of adversity.
# - **Freedom to Make Life Choices**: Somalia’s limited freedom is linked to political instability and conflict, which restricts opportunities and autonomy, impacting citizens' happiness. However, strong community bonds help mitigate some of these effects.
#
#
# The visualization below highlights these factors across the selected countries.

# %% [markdown]
# ##Least happiest countries in Africa

# %%
# Filter the data for African countries only (Sub-Saharan Africa and Middle East and Northern Africa)
african_countries_data = happiness[happiness['Region'].isin(['Sub-Saharan Africa'])]

# Remove rows with missing Happiness Scores if any
african_countries_data = african_countries_data.dropna(subset=['Happiness Score'])

# Sort the countries by Happiness Score in ascending order (bottom happiest first)
sorted_african_countries_bottom = african_countries_data.sort_values(by='Happiness Score', ascending=True)

# Get the bottom 10 happiest countries (least happy)
bottom_10_happiest_african_countries = sorted_african_countries_bottom[['Country', 'Happiness Score']].head(10)

# Plot the bottom 10 happiest countries in Africa
plt.figure(figsize=(10, 6))
sns.barplot(x='Happiness Score', y='Country', data=bottom_10_happiest_african_countries, palette='coolwarm')
plt.title('Bottom 10 Happiest Countries in Africa')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-26-804cad06c56f>:15: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
# Sort the data by Happiness Score in ascending order (lowest happiness score first)
least_happy_countries = african_countries_data.sort_values(by='Happiness Score', ascending=True).head(10)

# Melt the data for the selected least happy countries
melted_data = least_happy_countries.melt(
    id_vars=['Country'],
    value_vars=['Economy (GDP per Capita)', 'Social support', 'Freedom to make life choices'],
    var_name='Factor',
    value_name='Score'
)

# Create the interactive bar plot
fig = px.bar(
    melted_data,
    x='Country',
    y='Score',
    color='Factor',
    barmode='group',
    title='Comparison of Key Factors Contributing to Happiness in the Least Happiest African Countries',
    labels={'Score': 'Score', 'Country': 'Country'},
)

# Update layout for readability
fig.update_layout(
    xaxis_title='Country',
    yaxis_title='Score',
    legend_title='Happiness Factors'
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Insights for the Least Happiest African Countries: CAR, Togo, South Sudan, Burundi, and Tanzania
#
# ### 1. **Central African Republic (CAR)**
#
# - **GDP per Capita**:
#   CAR has the lowest GDP per capita among these countries, reflecting its economic instability and underdevelopment. A low GDP per capita means fewer resources for basic services such as healthcare, education, infrastructure, and job creation. This directly impacts the overall happiness of the citizens, as economic challenges lead to higher poverty rates and lower quality of life.
#
# - **Social Support**:
#   Despite the challenging economic conditions, **CAR** ranks highest in social support. Strong community ties, family networks, and solidarity within local groups can provide a sense of belonging and resilience, which contributes positively to happiness. People in CAR rely heavily on their social circles to support one another, especially in times of crisis. This strong social network helps buffer the effects of the country's poor economic situation.
#
# - **Freedom to Make Life Choices**:
#   Unfortunately, **CAR** ranks last in terms of freedom to make life choices. The ongoing political instability, insecurity, and lack of basic government infrastructure severely limit personal freedoms. Citizens often face restrictions on their autonomy, which can lead to frustration, helplessness, and low overall happiness. The lack of freedom to make personal decisions further adds to the struggle, reducing the potential for individual fulfillment.
#
# **Summary**: Despite **CAR’s** strong social support system, its low GDP and lack of personal freedom make it one of the least happy countries in Africa.
#
# ---
#
# ### 2. **Togo**
#
# - **GDP per Capita**:
#   **Togo** ranks higher than CAR in GDP per capita but still faces significant economic challenges. The country has a relatively low GDP per capita, which reflects limited access to economic opportunities and services like healthcare and education. Despite improvements in certain sectors, economic inequality remains high, and many citizens struggle to make ends meet.
#
# - **Social Support**:
#   **Togo** has relatively weaker social support than **CAR** and **Burundi**, though it still benefits from some degree of community and family ties. Social support is vital in challenging environments, and while **Togo** does offer some support structures, they are not as robust as those in the top-ranked countries, resulting in a somewhat weaker safety net for citizens.
#
# - **Freedom to Make Life Choices**:
#   **Togo** ranks moderately in terms of personal freedom. Citizens can exercise certain freedoms, such as making decisions about their careers or education, but there are still significant political and societal constraints. The lack of full political freedom and opportunities for personal advancement in certain areas affects citizens' overall happiness.
#
# **Summary**: **Togo’s** moderate GDP, combined with moderate social support and limited freedom, leaves its citizens with a relatively low happiness level. However, its economic position is still slightly better than **CAR’s**.
#
# ---
#
# ### 3. **South Sudan**
#
# - **GDP per Capita**:
#   **South Sudan** has a higher GDP per capita than **Burundi** and **CAR**, primarily due to its oil resources. However, the country’s GDP per capita remains low compared to regional standards, and the wealth generated is unevenly distributed. The ongoing civil war, corruption, and political instability have hindered the country’s development, limiting the benefits that should come with its natural resources.
#
# - **Social Support**:
#   **South Sudan** faces significant challenges in terms of social support. Due to the ongoing conflict and humanitarian crisis, many people live in displacement camps or unstable environments where social structures have been severely disrupted. Limited access to healthcare, education, and government services weakens the social support system, making it harder for citizens to rely on their communities.
#
# - **Freedom to Make Life Choices**:
#   **South Sudan** ranks low in terms of personal freedom. The country’s ongoing conflict and political repression leave little room for individuals to exercise their basic freedoms. The lack of security, political freedom, and personal autonomy restricts the ability of citizens to make meaningful choices about their futures, which contributes significantly to the low happiness levels.
#
# **Summary**: **South Sudan**’s relatively higher GDP is overshadowed by its lack of social support and personal freedom, leaving its citizens with limited opportunities for happiness.
#
# ---
#
# ### 4. **Burundi**
#
# - **GDP per Capita**:
#   **Burundi** has a very low GDP per capita, similar to **Togo** and **South Sudan**. The country faces significant poverty, with many citizens living below the poverty line. Limited access to education, healthcare, and economic opportunities means that many people struggle to improve their quality of life. Despite efforts to improve its economy, Burundi remains one of the poorest countries in the world.
#
# - **Social Support**:
#   **Burundi** ranks second for social support in this analysis, after **CAR**. The people of Burundi have strong community ties, and family networks provide crucial support in difficult times. While the economy is struggling, the strong sense of social cohesion and reliance on each other offers a certain level of comfort, contributing to higher happiness compared to countries with weaker social networks.
#
# - **Freedom to Make Life Choices**:
#   **Burundi** leads in terms of freedom, offering its citizens relatively higher levels of personal freedom compared to countries like **South Sudan** and **CAR**. However, political instability and repression still restrict personal freedoms to some extent. Despite these challenges, people in **Burundi** have more control over their decisions, including in areas such as education and career choices, which contributes to a higher sense of autonomy and happiness.
#
# **Summary**: **Burundi** ranks highest in freedom and social support, although its low GDP limits its overall happiness potential. Still, its relatively stronger social systems and personal freedoms provide a buffer against economic hardship.
#
# ---
#
# ### 5. **Tanzania**
#
# - **GDP per Capita**:
#   **Tanzania** has the highest GDP per capita among the countries in this analysis. The economy, driven by agriculture, mining, and tourism, is relatively larger compared to the others. While Tanzania faces its own economic challenges, it is in a better position economically than **South Sudan**, **Togo**, and **Burundi**, with its citizens benefiting from slightly better living standards and access to services.
#
# - **Social Support**:
#   **Tanzania** has moderate social support, which contributes to citizens’ well-being. Social networks, family, and community ties provide some level of emotional and financial support. However, the country’s infrastructure challenges and regional disparities mean that social support systems are not as universally robust as in **CAR** or **Burundi**.
#
# - **Freedom to Make Life Choices**:
#   **Tanzania** ranks third in terms of freedom. While citizens enjoy certain freedoms, political and societal challenges remain. Limited political pluralism and government restrictions affect the degree of autonomy individuals have, but Tanzanians generally have more control over their lives compared to countries like **South Sudan** or **CAR**.
#
# **Summary**: **Tanzania** stands out for its relatively higher GDP per capita, moderate social support, and reasonable levels of personal freedom. These factors make it the most economically and socially stable among the five countries, though it still faces significant challenges in all areas.
#
# ---
#
# ### **Conclusion**
#
# While all five countries — **CAR**, **Togo**, **South Sudan**, **Burundi**, and **Tanzania** — face challenges that contribute to their low happiness scores, the factors of **GDP per Capita**, **Social Support**, and **Freedom to Make Life Choices** each play a significant role in shaping citizens' well-being.
#
# - **CAR**, with its low GDP, lack of freedom, but strong social support, faces the most difficult conditions for its citizens.
# - **Togo** and **South Sudan** have better economic conditions than **CAR**, but weaker social support and freedom prevent significant improvements in happiness.
# - **Burundi** stands out for its relative freedoms and social support, which help mitigate its poor economic situation.
# - **Tanzania**, with the best economic standing, has moderate social support and freedom, contributing to its relatively higher happiness compared to the others.
#
# By understanding these relationships, policymakers can target key areas such as improving economic conditions, strengthening social support networks, and increasing personal freedoms to enhance the happiness of their populations.

# %% [markdown]
# #Comparison of the happiest country in the world with the least happiest country

# %%
# Get the happiest country (highest Happiness Score)
happiest_country = happiness.sort_values(by='Happiness Score', ascending=False).iloc[0]

# Get the least happiest country (lowest Happiness Score)
least_happy_country = happiness.sort_values(by='Happiness Score', ascending=True).iloc[0]

# Print the happiest and least happiest countries
print(f"The happiest country in the world is {happiest_country['Country']} with a Happiness Score of {happiest_country['Happiness Score']}.")
print(f"The least happiest country in the world is {least_happy_country['Country']} with a Happiness Score of {least_happy_country['Happiness Score']}.")
# Out:
# The happiest country in the world is Finland with a Happiness Score of 7.769.
# The least happiest country in the world is Central African Republic with a Happiness Score of 2.693000078.

# %%
import plotly.express as px
import pandas as pd

# Filter data for Finland and Central African Republic
countries_to_compare = ['Finland', 'Central African Republic']
comparison_data = happiness[happiness['Country'].isin(countries_to_compare)]

# Melt the data to make it long format for easier plotting
melted_data = comparison_data.melt(
    id_vars=['Country'],
    value_vars=['Economy (GDP per Capita)', 'Social support', 'Freedom to make life choices'],
    var_name='Factor',
    value_name='Happiness Score'
)

# Create the bar plot using Plotly Express
fig = px.bar(
    melted_data,
    x='Country',
    y='Happiness Score',
    color='Factor',  # Color bars by Factor
    barmode='group',  # Group bars for each country
    title="Comparison of Happiness Factors: Finland vs Central African Republic",
    labels={'Score': 'Score', 'Country': 'Country'}
)

# Update layout for readability
fig.update_layout(
    xaxis_title='Country',
    yaxis_title='Happiniess Score',
    legend_title='Factors'
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Finland:
# - **GDP per Capita (Nominal)**: Finland has one of the highest GDP per capita in the world. According to the World Bank, Finland's GDP per capita for 2022 was approximately **$56000**. This high economic standing contributes to an elevated standard of living and access to quality public services for Finnish citizens.
#
# - **Economic Growth**: Finland's economy is known for its resilience, high productivity, and innovation-driven industries such as technology (e.g., Nokia), clean energy, and high-tech manufacturing.
#
# - **Social Support**: Finland ranks high in social support, with a strong welfare system that provides access to comprehensive healthcare, education, and social security benefits. This social safety net promotes equality and enhances life satisfaction by reducing financial and social inequalities among citizens.
#
# - **Freedom to Make Life Choices**: Finland is known for its high degree of personal freedom. Citizens enjoy substantial autonomy to make life choices in areas such as education, career paths, and family life. This freedom fosters a culture of personal responsibility and empowerment, leading to greater happiness and fulfillment.
#
# - **Economic Growth**: Finland’s economy is characterized by resilience and high productivity. It excels in innovation, particularly in sectors like technology (with companies like Nokia), clean energy, and advanced manufacturing. This diverse, innovation-driven economy supports stable growth and job creation, bolstering national prosperity and citizen well-being.
#
# ### Central African Republic (CAR):
# - **GDP per Capita (Nominal)**: The Central African Republic has one of the lowest GDP per capita in the world. For 2022, CAR's GDP per capita was estimated at around **$500**. This low economic output reflects limited industrialization and a heavy reliance on subsistence farming, which restricts access to basic services and economic opportunities.
#
# - **Economic Challenges**: CAR's economy is heavily impacted by political instability, conflict, and a lack of infrastructure. The country remains one of the poorest in the world, with minimal industrialization and a reliance on agriculture, particularly subsistence farming.
#
# - **Social Support**: CAR faces significant challenges in social support due to ongoing conflict, political instability, and underdeveloped social infrastructure. The limited healthcare, education, and social welfare systems result in reduced support for citizens, who often rely on community and family networks for assistance.
#
# - **Freedom to Make Life Choices**: In CAR, personal freedom is severely constrained by political unrest, economic hardship, and limited educational and career opportunities. These factors restrict individuals’ ability to make independent life choices, affecting their overall well-being and sense of autonomy.
#
# - **Economic Challenges**: The Central African Republic’s economy is hindered by a lack of infrastructure, political instability, and frequent conflicts. As one of the poorest countries globally, CAR has minimal industrial activity, limited foreign investment, and relies heavily on agriculture, particularly subsistence farming, to sustain its population.
